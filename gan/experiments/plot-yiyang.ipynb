# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib


def plot_loss(file_name):
    train_loss = []   # This is actually psnr
    val_loss = []     # This is actually loss
    train_loss_G = []
    train_loss_D = []
    counter = 0
    print("here")
    with open(file_name) as txtfile:
        for row in txtfile:
            row = row.strip()
            row = row.split(" ")
            if len(row) >= 16:
#                 print(row[11:])
#                 print(row[12]) # gloss
#                 print(row[15]) # dloss
                train_loss_G.append(row[12])
                train_loss_D.append(row[15])
#             if counter < 365:
#                 counter += 1
#                 continue
#             curt_row = row.split(' ')
#             if len(curt_row) >= 0 : 
# #                 print (curt_row[-5])
#                 if curt_row[3] == 'Train' and curt_row[-5] == 'g_loss:':
# #                     print(curt_row[-4])
#                     train_loss_G.append(float(curt_row[-4]))
# #                     print(curt_row[15])
#                     train_loss_D.append(float(curt_row[15]))

                    
#     print (train_loss)
#     train_loss = train_loss[2:]
#     train_loss_D = train_loss_D[:20]
#     train_loss_new_D = []
#     for i in range(len((train_loss_D)) - 1):
#         train_loss_new_D.append(train_loss_D[i])
#         train_loss_new_D.append((0.75 * train_loss_D[i] + 0.25 * train_loss_D[i+1]))
#         train_loss_new_D.append((train_loss_D[i] + train_loss_D[i+1]) / 2)
#         train_loss_new_D.append((0.25 * train_loss_D[i] + 0.75 * train_loss_D[i+1]))

#     val_loss = val_loss[:]
    plt.figure()
    plt.plot(train_loss_G[:100])
    plt.plot(train_loss_D[:100])
    plt.show()
    plt.figure()
    plt.plot(train_loss_G[:])
    plt.plot(train_loss_D[:])
    plt.show()

# cgan = './cgan_model/train.log'
gan = './gan_model/train.log'
# gan_mse = './gan_mse_model/train.log'
gan_ssim = './gan_ssim_model/train.log'
# gan_notv = './gan_notv_model/train.log'


# plot_loss(cgan)
plot_loss(gan)
# plot_loss(gan_mse)
plot_loss(gan_ssim)
# plot_loss(gan_notv)


# plt.plot(val_loss)
plt.legend(['train_loss_G','train_loss_D'])
plt.xlabel('Number of epochs')
plt.ylabel('Loss(MSE)')
plt.title('Loss vs Num of Epochs')
plt.show()
# Out:
# here
# here

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib


def plot_loss(file_name):
    train_loss = []   # This is actually psnr
    val_loss = []     # This is actually loss
    train_loss_G = []
    train_loss_D = []
    counter = 0
    with open(file_name) as txtfile:
        for row in txtfile:
            row = row.strip()
            row = row.split(" ")
            if row[3] == "Train":
                print(row[-1])
                train_loss.append(row[-1])
            elif row[3] == "Eval":
                print(row[-1])
                val_loss.append(row[-1])
#                 if len(row) >= 100:
#                     print(row[:])
#                     print(row[12]) # gloss
#                     print(row[15]) # dloss
    #                 train_loss_G.append(row[12])
    #                 train_loss_D.append(row[15])
        
    plt.figure()
    plt.plot(train_loss[-85:])
    plt.plot(val_loss[-85:])
    plt.show()
#     plt.figure()
#     plt.plot(train_loss[:])
#     plt.plot(val_loss[:])
#     plt.show()

# cgan = './cgan_model/train.log'
gan = './gan_model/loss.txt'
# gan_mse = './gan_mse_model/train.log'
gan_ssim = './gan_ssim_model/train.log'
gan_notv = './gan_notv_model/train.log'


# plot_loss(cgan)
plot_loss(gan)
# plot_loss(gan_mse)
# plot_loss(gan_ssim)
# plot_loss(gan_notv)


# plt.plot(val_loss)
# plt.legend(['train_loss_G','train_loss_D'])
# plt.xlabel('Number of epochs')
# plt.ylabel('Loss(MSE)')
# plt.title('Loss vs Num of Epochs')
# plt.show()
# Out:
# 5256.681
# 5206.057
# 4923.144
# 5163.270
# 4553.335
# 5121.034
# 4139.370
# 5076.964
# 3695.171
# 5027.244
# 3243.428
# 4964.732
# 2799.811
# 4875.591
# 2371.194
# 4737.572
# 1979.977
# 4520.147
# 1673.602
# 4192.138
# 1482.890
# 3744.012
# 1382.127
# 3212.288
# 1315.990
# 2672.615
# 1252.836
# 2202.506
# 1194.608
# 1853.557
# 1146.775
# 1648.542
# 1099.060
# 1562.576
# 1044.808
# 1518.257
# 995.412
# 1450.381
# 960.105
# 1357.778
# 929.717
# 1264.320
# 894.951
# 1181.874
# 858.623
# 1114.190
# 827.721
# 1063.179
# 804.410
# 1028.219
# 785.184
# 1004.710
# 765.426
# 986.889
# 743.738
# 971.085
# 721.885
# 955.784
# 701.604
# 939.518
# 682.460
# 920.286
# 663.130
# 898.466
# 643.989
# 879.076
# 627.294
# 867.879
# 615.126
# 865.990
# 607.216
# 869.198
# 600.709
# 871.224
# 592.334
# 867.378
# 581.292
# 855.730
# 569.360
# 837.273
# 558.594
# 815.631
# 549.517
# 795.313
# 541.371
# 778.558
# 533.348
# 764.026
# 525.398
# 749.950
# 517.883
# 736.468
# 510.468
# 723.287
# 502.547
# 709.436
# 494.567
# 696.040
# 487.670
# 685.332
# 358.264
# 208.770
# 215.234
# 188.538
# 185.973
# 184.179
# 176.635
# 178.719
# 189.931
# 175.395
# 168.442
# 172.288
# 170.118
# 170.947
# 159.078
# 167.404
# 155.344
# 167.909
# 188.837
# 166.818
# 158.989
# 167.879
# 173.391
# 176.846
# 167.965
# 164.402
# 168.935
# 175.018
# 171.153
# 162.588
# 157.853
# 163.047
# 165.332
# 162.836
# 151.324
# 160.918
# 169.609
# 161.355
# 161.616
# 160.665
# 161.080
# 161.154
# 141.877
# 161.331
# 142.682
# 160.638
# 146.778
# 159.865
# 154.777
# 160.131
# 154.333
# 160.047
# 160.692
# 160.173
# 160.967
# 159.289
# 145.209
# 159.272
# 148.624
# 159.349
# 156.309
# 158.406
# 150.568
# 158.420
# 164.141
# 158.999
# 176.022
# 159.350
# 160.220
# 158.819
# 183.364
# 158.517
# 154.239
# 158.226
# 152.905
# 157.730
# 165.896
# 159.712
# 161.722
# 159.364
# 165.034
# 158.620
# 162.282
# 158.681
# 152.403
# 157.820
# 148.345
# 159.729
# 140.699
# 159.118
# 166.202
# 159.499
# 154.146
# 158.967
# 147.795
# 158.582
# 165.259
# 157.383
# 145.145
# 158.070
# 138.730
# 158.132
# 150.495
# 157.555
# 150.675
# 157.696
